# %% [markdown]
# Calculate the feature importance of the pixels in the images of the CIFAR-10
#  dataset (combine train and test sets) using a random forest classifier

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
from sklearn.datasets import fetch_openml
cifar = fetch_openml('cifar_10')
x, y = cifar["data"], cifar["target"]

print(x.shape)
print(y.shape)
# Out:
# (60000, 3072)
# (60000,)

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import numpy as np

rf_clf = RandomForestClassifier(n_estimators=100, random_state = 0)
rf_clf.fit(x, y)
# Out:
# RandomForestClassifier(random_state=0)

# %%
importances = rf_clf.feature_importances_.reshape(48,64)
plt.imshow(importances, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.title("Pixel Importance")
plt.show()
